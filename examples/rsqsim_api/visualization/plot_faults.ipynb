# %%
# Import relevant modules
from rsqsim_api.fault.multifault import RsqSimMultiFault
import os
import fnmatch

# Tell python where field paths etc are relative to
script_dir = os.path.abspath('')
fault_dir = "../../../data/shaw2021/rundir5091"
catalogue_dir = fault_dir

# %% [markdown]
# Read in fault model and catalogue.
# The files are quite large and can be downloaded from https://doi.org/10.5281/zenodo.5534462

# %%
fault_model = RsqSimMultiFault.read_fault_file_bruce(os.path.join(script_dir, fault_dir, "zfault_Deepen.in"),
                                                     os.path.join(script_dir, fault_dir, "znames_Deepen.in"),
                                                     transform_from_utm=True)

# %% [markdown]
# Examples of searching for faults or listing fault names

# %%
hik = [name for name in fault_model.names if fnmatch.fnmatch(name, "hik*")]
puy = ['fiordsz03', 'fiordpusz09']

# %% [markdown]
# Plot faults

# %%
fault_model.plot_faults_2d(puy)
# Out:
# /home/camilla/PycharmProjects/rsqsim-python-tools/src/rsqsim_api/rsqsim_api/visualisation/utilities.py:79: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   poly_ls += list(item)
# /home/camilla/PycharmProjects/rsqsim-python-tools/src/rsqsim_api/rsqsim_api/visualisation/utilities.py:79: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   poly_ls += list(item)

# %%
# Out:
# ['greendale',
#  'ahuririr',
#  'akaotaki',
#  'akatore',
#  'albury',
#  'aldermane01',
#  'aldermane02',
#  'aldermane03',
#  'aldermane04',
#  'aldermane05',
#  'aldermane06',
#  'aldermane07',
#  'aldermanw01',
#  'aldermanw02',
#  'aldermanw03',
#  'aldermanw04',
#  'aldermanw05',
#  'alfmakuri',
#  'alpinef2k',
#  'alpinek2t',
#  'alpiner',
#  'ararata',
#  'aratiatia',
#  'arielbank',
#  'arieleast',
#  'arielnorth',
#  'ashley',
#  'astrolabe01',
#  'astrolabe02',
#  'astrolabe03',
#  'astrolabe04',
#  'astrolabe05',
#  'astrolabe06',
#  'astrolabe07',
#  'astrolabe08',
#  'awakeri',
#  'awaterene',
#  'awateresw',
#  'awatnever',
#  'awatnevercl',
#  'barefell',
#  'bidwill',
#  'billys',
#  'bluelk',
#  'bluemtn',
#  'boobooall',
#  'braemar',
#  'brothers',
#  'browning',
#  'brunant',
#  'calypso02',
#  'calypso03',
#  'cardronan',
#  'cardronas',
#  'carterton',
#  'caswell1',
#  'caswell211',
#  'caswell3',
#  'caswell4',
#  'caswell5',
#  'caswellh10',
#  'caswellh67',
#  'caswellh8',
#  'caswellh9',
#  'cballeny',
#  'cegmontc',
#  'cegmontn',
#  'cegmonts',
#  'chalky1to3',
#  'chalky4to8',
#  'cheeseman',
#  'clarencecentr',
#  'clarencene',
#  'clarencesw',
#  'cust',
#  'cw4swedge411',
#  'cwedge123',
#  'dalgety',
#  'domino02',
#  'doublehill',
#  'dryburgh',
#  'dryhuang',
#  'dunstan',
#  'edgecumb87',
#  'edgecumbcs',
#  'esk',
#  'feildingant',
#  'ferngully',
#  'fernsidef28',
#  'fidget',
#  'fiordmar1&2',
#  'fiordsz03',
#  'fiordpusz09',
#  'fisherman',
#  'fivefingers',
#  'fowlers',
#  'foxpk',
#  'gableend',
#  'galpin',
#  'georger1',
#  'gimmerburn',
#  'grandview',
#  'hanmer',
#  'harper',
#  'hauroko',
#  'hawkebay1',
#  'hawkebay2',
#  'hawkebay4',
#  'hawkebay5&11',
#  'hawkebay6&12',
#  'hawkebay7',
#  'hawkebay8',
#  'hikhbaymax',
#  'hikraukmax',
#  'hikwgtnmax',
#  'himatangiant',
#  'hokonui',
#  'hollyford',
#  'honeycomb',
#  'hope1888',
#  'hopeconway',
#  'hopeconwayos',
#  'hopecw',
#  'hopetara',
#  'hopeterapa1n2',
#  'horohoro',
#  'hororata',
#  'hossack',
#  'houtunui',
#  'humpr',
#  'hundalee',
#  'hunter',
#  'huttpeelnorth',
#  'huttpeelsouth',
#  'hyde',
#  'inangahua',
#  'inglewood',
#  'irishmanc',
#  'jorkekcha',
#  'jorkekneed',
#  'kaiapo',
#  'kaingaroa',
#  'kairakau2',
#  'kairakaun',
#  'kairakaus',
#  'kaiwaran',
#  'kaiwaras',
#  'kakapo',
#  'karioi',
#  'kaumingi',
#  'kaweka',
#  'kekerengubf',
#  'kelly',
#  'kerepehic',
#  'kerepehin',
#  'kerepehio',
#  'kerepehis',
#  'kidnappersr',
#  'kirkliston',
#  'lachlan1&2',
#  'lachlan3',
#  'leedstown',
#  'leesv',
#  'levinant',
#  'lindisp',
#  'lkheron',
#  'longvlly',
#  'lowry',
#  'lyell',
#  'madden',
#  'mahia2',
#  'maimai',
#  'maketu01',
#  'maketu02',
#  'maketu03',
#  'maleme',
#  'manaota',
#  'mangatete',
#  'martinborough',
#  'martonant',
#  'mascarin',
#  'masterton',
#  'mataikona',
#  'mataroa',
#  'matata',
#  'matatara01',
#  'matatara02',
#  'matatara03',
#  'matatara04',
#  'maungatie01',
#  'maungatiw01',
#  'maungatiw02',
#  'maungatiw03',
#  'milb5geor2',
#  'milfordb1',
#  'mohakan',
#  'mohakas',
#  'mokonuine',
#  'mokonuisw',
#  'moonlightnth',
#  'moonlightsth',
#  'moonshine',
#  'motuhoras01',
#  'motuokurae',
#  'motuokuran',
#  'motuokurar',
#  'moumahokaia4',
#  'moutoki01',
#  'moutoki02',
#  'ms01',
#  'ms02',
#  'ms04',
#  'ms05',
#  'ms09',
#  'mtstew',
#  'mtwhite',
#  'napier1931',
#  'nationalpk',
#  'nevis',
#  'ngakurunew',
#  'ngakurusw',
#  'ngangiho',
#  'ngapouri',
#  'ngatoros01',
#  'ngatoros02',
#  'ngatoros03',
#  'ngatoros04',
#  'ngatoros05',
#  'ngatoros06',
#  'nmfz1819',
#  'nmfz4647',
#  'nmfzb0',
#  'nmfzb1',
#  'nmfzb2',
#  'nmfze1',
#  'nmfze2',
#  'nmfzf1',
#  'nmfzf2',
#  'nmfzk1',
#  'nmfzk2',
#  'nmfzm',
#  'nohariu',
#  'northbranch',
#  'northcant1',
#  'northcant10',
#  'northcant11',
#  'northcant13',
#  'northcant2',
#  'northcant4',
#  'northcant8',
#  'nukuhou01',
#  'nukwaitot1to6',
#  'oaonui',
#  'ohae01',
#  'ohae02',
#  'ohae03',
#  'ohakune',
#  'ohakuri',
#  'ohariuc',
#  'oharius',
#  'ohena01',
#  'ohena02',
#  'ohena03',
#  'ohena04',
#  'ohiwa01',
#  'ohiwanorth01',
#  'okaia3',
#  'okaia5',
#  'okupe',
#  'okurei01',
#  'okurei02',
#  'okurei03',
#  'okurei04',
#  'okurei05',
#  'okurei06',
#  'oldman',
#  'omakerer',
#  'omakeres',
#  'omihi',
#  'onepoto',
#  'opawa',
#  'opotiki02',
#  'opotiki03',
#  'opouaweuruti',
#  'orakeikorako',
#  'orakonui',
#  'oruakukuru',
#  'oruawharo',
#  'ostler',
#  'otakiri',
#  'otaraeast01',
#  'otaraeast02',
#  'otaraeast03',
#  'otaraeast04',
#  'otaraeast05',
#  'otaraeast06',
#  'otaraia',
#  'otarawest01',
#  'otarawest02',
#  'otarawest03',
#  'otematata',
#  'otokototof7',
#  'paeroaall',
#  'pahaua',
#  'pahiatua',
#  'palliserkai',
#  'pangopangof29',
#  'paoanuirn',
#  'paoanuirs',
#  'paparoarf',
#  'paritur',
#  'parituw',
#  'patokarang',
#  'pavalley',
#  'pegasus1nw',
#  'piripai01',
#  'pisa',
#  'pohanginaant',
#  'pokare01',
#  'pokare02',
#  'pongaroaweber',
#  'poranagr',
#  'poranagw1',
#  'poranagw2',
#  'poroutawhao',
#  'port2greys',
#  'port2greyl',
#  'poulter',
#  'poutu',
#  'povertybay',
#  'pukeshep',
#  'puketerata',
#  'pukn-1',
#  'pukn-2',
#  'quartzck',
#  'raetihi',
#  'raggedy',
#  'rakaia',
#  'ran-01',
#  'ran-02',
#  'ranfurly',
#  'rangioffsh',
#  'rangipoc',
#  'rangipon',
#  'rangipos',
#  'rangitikei',
#  'raukumaraf13',
#  'raukumaraf15',
#  'raukumaraf16',
#  'raukumaraf17',
#  'raukumaraf18',
#  'raukumaraf19',
#  'raukumaraf2',
#  'raukumaraf21',
#  'raukumaraf22',
#  'raukumaraf23',
#  'raurimu',
#  'repongaeref4',
#  'ridgerokaia2',
#  'ritchier',
#  'ritchiew1',
#  'ritchiew2',
#  'riversdale',
#  'rotoiti',
#  'ruahinec',
#  'ruahinen',
#  'ruahinerev',
#  'ruahines',
#  'ruataniwha',
#  'ruatorias1',
#  'ruatorias2',
#  'saunwaipukaka',
#  'settlement',
#  'sfiordmg13',
#  'sfiordmg1to9',
#  'shannona',
#  'shawcroftrd',
#  'snowgrass',
#  'solander',
#  'springbank',
#  'springfield',
#  'spylaw',
#  'stonewall',
#  'swedge1',
#  'swedge2',
#  'swedge3',
#  'swedge5',
#  'swedge6to10',
#  'taierir',
#  'taihape',
#  'takitimu1',
#  'takitimu2',
#  'tarawera01',
#  'tarawera03',
#  'tarawera04',
#  'tarawera05',
#  'tauranga01',
#  'tauranga02',
#  'tauranga03',
#  'tauranga04',
#  'tauranga05',
#  'taurtre01',
#  'taurtre02',
#  'taurtre03',
#  'taurtre04',
#  'taurtre05',
#  'taurtre06',
#  'taurtrw01',
#  'taurtrw02',
#  'taurtrw03',
#  'taurtrw04',
#  'taurtrw05',
#  'teanau',
#  'tearawa01',
#  'tearawa03',
#  'tewhaiti',
#  'tewheta',
#  'thornton01',
#  'thornton02',
#  'tokata01',
#  'torlesse',
#  'treetrunk',
#  'tuahenir',
#  'tuahu',
#  'tuakana01',
#  'tuakana02',
#  'tuakana03',
#  'tuakana04',
#  'tuakana05',
#  'tuakana06',
#  'tuakana07',
#  'tuakana08',
#  'tuakana09',
#  'tuakana10',
#  'tuakana11',
#  'tuakana12',
#  'tuakana13',
#  'tuatoru01',
#  'tuatoru02',
#  'tuatoru03',
#  'tuhuan01',
#  'tuhuan02',
#  'tuhuan03',
#  'tuhuan04',
#  'tuhuan05',
#  'tuhuas01',
#  'tuhuas02',
#  'tuhuas03',
#  'tukitukithr',
#  'tumokemoke01',
#  'tumokemoke02',
#  'turic',
#  'turin',
#  'turis',
#  'upperslope',
#  'urewera1',
#  'urewera2',
#  'urewera3',
#  'urutibasin',
#  'urutie',
#  'urutin',
#  'urutir2',
#  'volkner01',
#  'volkner02',
#  'volkner03',
#  'volkner04',
#  'volkner05',
#  'wahianoa',
#  'waihie',
#  'waihis',
#  'waihiw',
#  'waikaremoana',
#  'waimanan',
#  'waimanas',
#  'waimarama1&2',
#  'waimarama3&4',
#  'waimeac',
#  'waimeas',
#  'waimean',
#  'waiohaun',
#  'waiohaus',
#  'waipiata',
#  'waipukpouk',
#  'waipuna',
#  'wairaka01',
#  'wairaka02',
#  'wairaka03',
#  'wairaka04',
#  'wairaka05',
#  'wairaka06',
#  'wairarapnich',
#  'wairata',
#  'wairau',
#  'wairoan',
#  'waitangi',
#  'waitawhiti',
#  'waitohi',
#  'waitot1011',
#  'waitot8to9',
#  'waverokaia1',
#  'wellp',
#  'wellteast',
#  'wellwhv',
#  'whakaari01',
#  'whakaari02',
#  'whakaari03',
#  'whakaari04',
#  'whakaipo',
#  'whakatanen',
#  'whakatanes',
#  'whangamata',
#  'whangamataw',
#  'wharatocampb',
#  'whareamabank',
#  'wharekauhau',
#  'wheaon',
#  'wheaos',
#  'whirinakiall',
#  'whirinakiw',
#  'whiteck',
#  'whiteis01',
#  'whiteis02',
#  'whiteis03',
#  'whiteisn01',
#  'whiteisn02',
#  'whitemans',
#  'wkm-1',
#  'woodville']
